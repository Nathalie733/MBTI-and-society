# %% [markdown]
# # MBTI and society

# %% [markdown]
# ![MBTI%20Types.jpeg](attachment:MBTI%20Types.jpeg)

# %% [markdown]
# ### MBTI, or the **Myers-Briggs Type Indicator**, is a popular personality framework based on psychological theories developed by Carl Jung. It categorizes people into 16 different personality types based on four pairs of preferences. These preferences are represented by four letters, each signifying a particular aspect of personality.
#
# ### **The Four Preferences (Letters) in MBTI:**
# Each of the four preferences is expressed as a pair of opposing traits. Your type is determined by selecting one trait from each pair:
#
# - **E (Extraversion) vs. I (Introversion)**
#    - **Extraversion (E)**: Focus on the outer world of people and activities.
#    - **Introversion (I)**: Focus on the inner world of thoughts and ideas.
#
# - **S (Sensing) vs. N (Intuition)**
#    - **Sensing (S)**: Focus on the present and concrete information gained from the senses.
#    - **Intuition (N)**: Focus on future possibilities and patterns, abstract ideas.
#
# - **T (Thinking) vs. F (Feeling)**
#    - **Thinking (T)**: Make decisions based on logic, objective analysis, and principles.
#    - **Feeling (F)**: Make decisions based on personal values and the impact on others.
#
# - **J (Judging) vs. P (Perceiving)**
#    - **Judging (J)**: Prefer a structured, organized lifestyle with decisions made early.
#    - **Perceiving (P)**: Prefer a flexible, spontaneous lifestyle and keep options open.
#
# Each individual is classified into one of the 16 personality types, for example: **ENFP, ISTJ, INFJ**, etc., by selecting one trait from each of the four pairs.

# %% [markdown]
# ## Why discover my personality?
#
# Through this, you can find your strengths and weaknesses, understand how you tend to think, analyze and perceive the world. And with this information, you can improve the way you study, work, deal with problems and highly emotional moments.

# %% [markdown]
# ## How to discover my personality?
#
# There are many ways to discover your personality. The best way is by understanding how each personality is constructed, studying the cognitive functions and the main personality traits; through this you can find the one that most identifies you. The easiest way is by taking a test. One of my favorites is: https://sakinorva.net/functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.ticker import FuncFormatter

# %%
df = pd.read_csv ('MBTI DATA.csv')
df
# Out:
#    Personality Total Population   Women     Men
# 0         INTJ            2.10%   0.90%   3.30%
# 1         INTP            3.30%   1.70%   4.80%
# 2         ENTJ            1.80%   0.90%   2.70%
# 3         ENTP            3.20%   2.40%   4.00%
# 4         INFJ            1.50%   1.60%   1.20%
# 5         INFP            4.40%   4.60%   4.10%
# 6         ENFJ            2.50%   3.30%   1.60%
# 7         ENFP            8.10%   9.70%   6.40%
# 8         ISTJ           11.60%   6.90%  16.40%
# 9         ISFJ           13.80%  19.40%   8.10%
# 10        ESTJ            8.70%   6.30%  11.20%
# 11        ESFJ           12.30%  16.90%   7.50%
# 12        ISTP            5.40%   2.30%   8.50%
# 13        ISFP            8.80%   9.90%   7.60%
# 14        ESTP            4.30%   3.00%   5.60%
# 15        ESFP            8.50%  10.10%   6.90%

# %%
df.dtypes
# Out:
# Personality         object
# Total Population    object
# Women               object
# Men                 object
# dtype: object

# %%
df['Total Population'] = df['Total Population'].str.rstrip('%').astype('float')

# %% [markdown]
# # 1. Total Population

# %% [markdown]
# ## 1.1 Let's analyze in a graph how the distribution is done

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Personality'], df['Total Population'], color='skyblue')
plt.title('Distribution of Personality Types in the Total Population', fontsize=12)
plt.xlabel('Personality', fontsize=12)
plt.ylabel('Percentage (%)', fontsize=12)
plt.ylim(0, 100) 
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.2 Now I want to see this with numbers, knowing that the current world population is 8,2 Billion

# %%
world_population = 8.2 * 10**9

# %%
df['Population Count'] = (df['Total Population'] / 100) * world_population

# %%
def billions(x, pos):
    return f'{int(x/1e9)}B'

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Personality'], df['Population Count'], color='skyblue')
plt.title('Estimated Number of People by Personality Type in a Population of 8.2 Billion', fontsize=12)
plt.xlabel('Personality', fontsize=12)
plt.ylabel('Number of People', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ylim(0, 8.2 * 10**9)

formatter = FuncFormatter(billions)
plt.gca().yaxis.set_major_formatter(formatter)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Women/Men Population

# %% [markdown]
# ## 2.1 Now, let's analyze how personalities are distributed according gender;

# %%
df['Women'] = df['Women'].str.replace('%', '').astype(float)
df['Men'] = df['Men'].str.replace('%', '').astype(float)

# %%
plt.figure(figsize=(12, 8))
bar_width = 0.35
index = range(len(df['Personality']))

plt.bar([i - bar_width / 2 for i in index], df['Women'], bar_width, label='Women', color='lightcoral')
plt.bar([i + bar_width / 2 for i in index], df['Men'], bar_width, label='Men', color='lightblue')

plt.xlabel('Personality Type')
plt.ylabel('Percentage (%)')
plt.title('Distribution of Personality Types by Gender')
plt.xticks(index, df['Personality'], rotation=45)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Conclusion

# %% [markdown]
# With these data we can already drawn into some conclusions about the behaviour of those personalities.

# %% [markdown]
# * The most common personality type in the world is ISFJ
#
# * The least common is INFJ
#
# * ISFJ is more common in females
#
# * ESFJ is the second most common, and is also more common in females
#
# * ISTJ is the third most common
#
# * ISTJ is more common in males
#
# * INTJ and ENTJ are the least common in females
#
# * INFJ is the least common in males
#
# * Men are more likely to be thinkers
#
# * Women are more likely to be feelers
#
# * The majority of the population is feelers
#
# * The majority of the population is introverted
#
# * The minority of the population is intuitive

# %% [markdown]
# I'm an intj woman, what about you? Take the test and have some fun understanding your personality.
